# %%
import malariagen_data

# %%
# Init API
adir1 = malariagen_data.Adir1(results_cache = '/Users/dennistpw/Projects/malariagen_results/')

# %%
# Are the contigs here? 
chroms = adir1.contigs[:5]
chroms[1]
# Out:
# 'KB672868'

# %%
snps = adir1.snp_calls(region="KB672868:1000000-2000000")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/github/tristanpwdennis/malariagen-data-python/malariagen_data/anoph/base.py:426, in AnophelesBase.sample_sets(self, release)
#     425 try:
# --> 426     df = self._cache_sample_sets[release]
#     428 except KeyError:
#     429     # Read and cache dataframe for performance.
#
# KeyError: '1.x'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 snps = adir1.snp_calls(region="KB672868:1000000-2000000")
#
# File ~/github/tristanpwdennis/malariagen-data-python/malariagen_data/util.py:1164, in check_types.<locals>.check_types_wrapper(*args, **kwargs)
#    1162             error = TypeError(message)
#    1163             raise error from None
# -> 1164 return f(*args, **kwargs)
#
# ...
