# %%
import malariagen_data
import ipyleaflet
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/malariagen/lib/python3.11/site-packages/requests/__init__.py:92: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %% [markdown]
# ## Ag3

# %%
ag3 = malariagen_data.Ag3(
    "simplecache::gs://vo_agam_release_master_us_central1",
    simplecache=dict(cache_storage="../gcs_cache"),
    debug=False,
)
ag3
# Out:
# <MalariaGEN Ag3 API client>
# Storage URL                           : simplecache::gs://vo_agam_release_master_us_central1
# Data releases available               : 3.0, 3.1, 3.2, 3.3, 3.4, 3.5, 3.6, 3.7, 3.8, 3.9, 3.10, 3.11, 3.12, 3.13, 3.14, 3.15, 3.16
# Results cache                         : None
# Cohorts analysis                      : 20260120
# AIM analysis                          : 20220528
# Site filters analysis                 : dt_20200416
# Software version                      : malariagen_data 15.8.0.post13+b769b728
# Client location                       : England, United Kingdom
# Data filtered to unrestricted use only: False
# Data filtered to surveillance use only: False
# Relevant data releases                : 3.0, 3.1, 3.2, 3.3, 3.4, 3.5, 3.6, 3.7, 3.8, 3.9, 3.10, 3.11, 3.12, 3.13, 3.14, 3.15, 3.16
# ---
# Please note that data are subject to terms of use,
# for more information see the Vector Observatory website https://www.malariagen.net/vobs/
# or contact support@malariagen.net. For API documentation see
# https://malariagen.github.io/malariagen-data-python/v15.8.0.post13+b769b728/Ag3.html

# %%
ag3.plot_samples_bar(x="country", sample_sets="3.0")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ag3.plot_samples_bar(x="country", sample_sets="3.0")
#
# File ~/malariagen-data-python/malariagen_data/util.py:1268, in _check_types.<locals>.wrapper(*args, **kwargs)
#    1265 @wraps(f)
#    1266 def wrapper(*args, **kwargs):
#    1267     try:
# -> 1268         return validated_f(*args, **kwargs)
#    1269     except ValidationError as e:
#    1270         type_hints = get_type_hints(f)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/malariagen/lib/python3.11/site-packages/pydantic/_internal/_validate_call.py:40, in update_wrapper_attributes.<locals>.wrapper_function(*args, **kwargs)
#      38 @functools.wraps(wrapped)
#      39 def wrapper_function(*args, **kwargs):
# ---> 40     return wrapper(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/malariagen/lib/python3.11/site-packages/pydantic/_internal/_validate_call.py:137, in ValidateCallWrapper.__call__(self, *args, **kwargs)
#     134 if not self.__pydantic_complete__:
#     135     self._create_validators()
# --> 137 res = self.__pydantic_validator__.validate_python(pydantic_core.ArgsKwargs(args, kwargs))
#     138 if self.__return_pydantic_validator__:
#     139     return self.__return_pydantic_validator__(res)
#
# File ~/malariagen-data-python/malariagen_data/anoph/sample_metadata.py:1435, in AnophelesSampleMetadata.plot_samples_bar(self, x, color, sort, sample_sets, sample_query, sample_query_options, sample_indices, template, width, height, show, renderer, **kwargs)
#    1432     fig.update_layout(legend_title=color.capitalize())
#    1434 if show:  # pragma: no cover
# -> 1435     fig.show(renderer=renderer)
#    1436 return fig
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/malariagen/lib/python3.11/site-packages/plotly/basedatatypes.py:3420, in BaseFigure.show(self, *args, **kwargs)
#    3387 """
#    3388 Show a figure using either the default renderer(s) or the renderer(s)
#    3389 specified by the renderer argument
#    (...)   3416 None
#    3417 """
#    3418 import plotly.io as pio
# -> 3420 return pio.show(self, *args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/malariagen/lib/python3.11/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %%
ag3.plot_samples_bar(x="country", color="taxon", sample_sets="3.0")

# %%
ag3.plot_samples_bar(x="year", color="country", sample_sets="3.0")

# %%
ag3.plot_samples_interactive_map(
    sample_sets=["3.0"],
    sample_query="year > 2009",
)

# %%
# Demo using a different basemap provider
# - The map background will appear grey if provision of tiles fails
tile_URL_pattern = "https://tile.openstreetmap.org/{z}/{x}/{y}.png"
ag3.plot_samples_interactive_map(
    sample_sets=["3.0"],
    basemap=ipyleaflet.TileLayer(url=tile_URL_pattern),
)

# %%
# See the available basemap abbreviations
malariagen_data.anoph.map_params.basemap_abbrevs.keys()

# %%
# Demo using a basemap abbreviation, case-insensitive
ag3.plot_samples_interactive_map(
    sample_sets=["3.0"],
    basemap="mapNik",
)

# %%
ag3.plot_sample_location_mapbox(
    color="country", sample_sets=["3.0"], sample_query="year > 2012", zoom=2
)

# %%
ag3.plot_sample_location_geo(
    color="country",
    sample_sets=["3.0"],
    sample_query="year > 2012",
)

# %% [markdown]
# ## Af1

# %%
af1 = malariagen_data.Af1(
    "simplecache::gs://vo_afun_release_master_us_central1",
    simplecache=dict(cache_storage="../gcs_cache"),
    debug=False,
    pre=True,
)
af1

# %%
af1.plot_samples_bar(x="country", sample_sets="1.0")

# %%
af1.plot_samples_bar(x="year", color="country", sample_sets="1.0")

# %%
# Demo using a basemap provider the same as one in its curated list
af1.plot_samples_interactive_map(
    sample_sets=["1.0"], basemap=ipyleaflet.basemaps.OpenTopoMap
)

# %%
af1.plot_sample_location_mapbox(
    color="country", sample_sets=["1.0"], sample_query="year > 2015", zoom=2
)

# %%
af1.plot_sample_location_geo(
    color="country",
    sample_sets=["1.0"],
    sample_query="year > 2015",
)

# %%
help(af1.plot_samples_bar)

# %%
help(af1.plot_samples_interactive_map)

# %%
help(af1.plot_sample_location_mapbox)

# %%
help(af1.plot_sample_location_geo)
