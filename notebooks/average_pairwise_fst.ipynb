# %% [markdown]
# NOTE: min_cohort_size and max_cohort_size parameters are not supported in current release for snp_allele_counts. The relevant code has been commented out here.

# %%
# !pip install malariagen_data
# Out:
# Collecting malariagen_data
#   Downloading malariagen_data-7.13.0-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.2/133.2 kB 3.9 MB/s eta 0:00:00
# Collecting BioPython (from malariagen_data)
#   Downloading biopython-1.81-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 58.8 MB/s eta 0:00:00
# Requirement already satisfied: bokeh>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from malariagen_data) (3.2.2)
# Collecting dash (from malariagen_data)
#   Downloading dash-2.14.1-py3-none-any.whl (10.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 101.3 MB/s eta 0:00:00
# Collecting dash-cytoscape (from malariagen_data)
#   Downloading dash_cytoscape-0.3.0-py3-none-any.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 87.2 MB/s eta 0:00:00
# Requirement already satisfied: dask[array] in /usr/local/lib/python3.10/dist-packages (from malariagen_data) (2023.8.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from malariagen_data) (2023.6.0)
# Requirement already satisfied: gcsfs in /usr/local/lib/python3.10/dist-packages (from malariagen_data) (2023.6.0)
# Collecting igv-notebook>=0.2.3 (from malariagen_data)
#   Downloading igv_notebook-0.5.2-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.5/302.5 kB 39.1 MB/s eta 0:00:00
# Collecting importlib_metadata<5.0 (from malariagen_data)
#   Downloading importlib_metadata-4.13.0-py3-none-any.whl (23 kB)
# Collecting ipinfo!=4.4.1 (from malariagen_data)
#   Downloading ipinfo-4.4.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: ipyleaflet>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from malariagen_data) (0.17.4)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from malariagen_data) (7.7.1)
# Collecting jupyter-dash (from malariagen_data)
#   Downloading jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Requirement already satisfied: llvmlite>0.34 in /usr/local/lib/python3.10/dist-packages (from malariagen_data) (0.39.1)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from malariagen_data) (0.56.4)
# Requirement already satisfied: numpy<1.25 in /usr/local/lib/python3.10/dist-packages (from malariagen_data) (1.23.5)
# Collecting numpydoc_decorator>=2.1.0 (from malariagen_data)
#   Downloading numpydoc_decorator-2.1.0-py3-none-any.whl (11 kB)
# Collecting orjson (from malariagen_data)
#   Downloading orjson-3.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from malariagen_data) (1.5.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from malariagen_data) (5.15.0)
# Collecting protopunica (from malariagen_data)
#   Downloading protopunica-0.14.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 50.4 MB/s eta 0:00:00
# Collecting scikit-allel (from malariagen_data)
#   Downloading scikit_allel-1.3.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 31.2 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from malariagen_data) (1.11.3)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from malariagen_data) (0.14.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from malariagen_data) (4.66.1)
# Collecting typeguard>=4.0.0 (from malariagen_data)
#   Downloading typeguard-4.1.5-py3-none-any.whl (34 kB)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from malariagen_data) (4.5.0)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from malariagen_data) (2023.7.0)
# Collecting zarr (from malariagen_data)
#   Downloading zarr-2.16.1-py3-none-any.whl (206 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.9/206.9 kB 21.7 MB/s eta 0:00:00
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from bokeh>=3.1.0->malariagen_data) (3.1.2)
# Requirement already satisfied: contourpy>=1 in /usr/local/lib/python3.10/dist-packages (from bokeh>=3.1.0->malariagen_data) (1.1.1)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.10/dist-packages (from bokeh>=3.1.0->malariagen_data) (23.2)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh>=3.1.0->malariagen_data) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.10/dist-packages (from bokeh>=3.1.0->malariagen_data) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.10/dist-packages (from bokeh>=3.1.0->malariagen_data) (6.3.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.10/dist-packages (from bokeh>=3.1.0->malariagen_data) (2023.10.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from igv-notebook>=0.2.3->malariagen_data) (5.5.6)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from igv-notebook>=0.2.3->malariagen_data) (7.34.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from igv-notebook>=0.2.3->malariagen_data) (2.31.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib_metadata<5.0->malariagen_data) (3.17.0)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from ipinfo!=4.4.1->malariagen_data) (5.3.2)
# Requirement already satisfied: aiohttp<=4 in /usr/local/lib/python3.10/dist-packages (from ipinfo!=4.4.1->malariagen_data) (3.8.6)
# Requirement already satisfied: traittypes<3,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from ipyleaflet>=0.17.0->malariagen_data) (0.2.1)
# Requirement already satisfied: branca>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from ipyleaflet>=0.17.0->malariagen_data) (0.6.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->malariagen_data) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->malariagen_data) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->malariagen_data) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->malariagen_data) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->malariagen_data) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->malariagen_data) (2023.3.post1)
# Collecting typing_extensions (from malariagen_data)
#   Downloading typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from dash->malariagen_data) (2.2.5)
# Requirement already satisfied: Werkzeug<3.1 in /usr/local/lib/python3.10/dist-packages (from dash->malariagen_data) (3.0.1)
# Collecting dash-html-components==2.0.0 (from dash->malariagen_data)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-core-components==2.0.0 (from dash->malariagen_data)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-table==5.0.0 (from dash->malariagen_data)
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting retrying (from dash->malariagen_data)
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Collecting ansi2html (from dash->malariagen_data)
#   Downloading ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from dash->malariagen_data) (1.5.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from dash->malariagen_data) (67.7.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->malariagen_data) (8.2.3)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from dask[array]->malariagen_data) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from dask[array]->malariagen_data) (2.2.1)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask[array]->malariagen_data) (1.4.1)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask[array]->malariagen_data) (0.12.0)
# Requirement already satisfied: decorator>4.1.2 in /usr/local/lib/python3.10/dist-packages (from gcsfs->malariagen_data) (4.4.2)
# Requirement already satisfied: google-auth>=1.2 in /usr/local/lib/python3.10/dist-packages (from gcsfs->malariagen_data) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.10/dist-packages (from gcsfs->malariagen_data) (1.0.0)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.10/dist-packages (from gcsfs->malariagen_data) (2.8.0)
# Requirement already satisfied: joblib>=0.9.0b4 in /usr/local/lib/python3.10/dist-packages (from protopunica->malariagen_data) (1.3.2)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.10/dist-packages (from protopunica->malariagen_data) (3.2)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels->malariagen_data) (0.5.3)
# Collecting asciitree (from zarr->malariagen_data)
#   Downloading asciitree-0.3.3.tar.gz (4.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting fasteners (from zarr->malariagen_data)
#   Downloading fasteners-0.19-py3-none-any.whl (18 kB)
# Collecting numcodecs>=0.10.0 (from zarr->malariagen_data)
#   Downloading numcodecs-0.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 78.8 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<=4->ipinfo!=4.4.1->malariagen_data) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<=4->ipinfo!=4.4.1->malariagen_data) (3.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<=4->ipinfo!=4.4.1->malariagen_data) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp<=4->ipinfo!=4.4.1->malariagen_data) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<=4->ipinfo!=4.4.1->malariagen_data) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<=4->ipinfo!=4.4.1->malariagen_data) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<=4->ipinfo!=4.4.1->malariagen_data) (1.3.1)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash->malariagen_data) (2.1.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.2->gcsfs->malariagen_data) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.2->gcsfs->malariagen_data) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.2->gcsfs->malariagen_data) (4.9)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel->igv-notebook>=0.2.3->malariagen_data) (6.1.12)
# Collecting jedi>=0.16 (from ipython->igv-notebook>=0.2.3->malariagen_data)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 63.5 MB/s eta 0:00:00
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->igv-notebook>=0.2.3->malariagen_data) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->igv-notebook>=0.2.3->malariagen_data) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->igv-notebook>=0.2.3->malariagen_data) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->igv-notebook>=0.2.3->malariagen_data) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->igv-notebook>=0.2.3->malariagen_data) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->igv-notebook>=0.2.3->malariagen_data) (4.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.9->bokeh>=3.1.0->malariagen_data) (2.1.3)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=1.2.0->dask[array]->malariagen_data) (1.0.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (6.5.5)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib->gcsfs->malariagen_data) (1.3.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage->gcsfs->malariagen_data) (2.11.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage->gcsfs->malariagen_data) (2.3.3)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage->gcsfs->malariagen_data) (2.6.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->igv-notebook>=0.2.3->malariagen_data) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->igv-notebook>=0.2.3->malariagen_data) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->igv-notebook>=0.2.3->malariagen_data) (2023.7.22)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage->gcsfs->malariagen_data) (1.61.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage->gcsfs->malariagen_data) (3.20.3)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage->gcsfs->malariagen_data) (1.5.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->igv-notebook>=0.2.3->malariagen_data) (0.8.3)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (5.4.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (5.9.2)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (6.5.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->igv-notebook>=0.2.3->malariagen_data) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->igv-notebook>=0.2.3->malariagen_data) (0.2.8)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs->malariagen_data) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs->malariagen_data) (3.2.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (3.11.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (0.2.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (2.18.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (4.19.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (21.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (0.10.6)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (1.6.4)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (1.1.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->malariagen_data) (2.21)
# Building wheels for collected packages: asciitree
#   Building wheel for asciitree (setup.py) ... done
#   Created wheel for asciitree: filename=asciitree-0.3.3-py3-none-any.whl size=5034 sha256=71baef97c4254300f5c7b8336e38306f4e9b233d8a5b53c932c8d0bef570fbc9
#   Stored in directory: /root/.cache/pip/wheels/7f/4e/be/1171b40f43b918087657ec57cf3b81fa1a2e027d8755baa184
# Successfully built asciitree
# Installing collected packages: dash-table, dash-html-components, dash-core-components, asciitree, typing_extensions, retrying, orjson, numcodecs, jedi, importlib_metadata, fasteners, BioPython, ansi2html, zarr, typeguard, protopunica, numpydoc_decorator, ipinfo, dash, scikit-allel, jupyter-dash, igv-notebook, dash-cytoscape, malariagen_data
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: importlib_metadata
#     Found existing installation: importlib-metadata 6.8.0
#     Uninstalling importlib-metadata-6.8.0:
#       Successfully uninstalled importlib-metadata-6.8.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.8.0 which is incompatible.
# Successfully installed BioPython-1.81 ansi2html-1.8.0 asciitree-0.3.3 dash-2.14.1 dash-core-components-2.0.0 dash-cytoscape-0.3.0 dash-html-components-2.0.0 dash-table-5.0.0 fasteners-0.19 igv-notebook-0.5.2 importlib_metadata-4.13.0 ipinfo-4.4.3 jedi-0.19.1 jupyter-dash-0.4.2 malariagen_data-7.13.0 numcodecs-0.12.1 numpydoc_decorator-2.1.0 orjson-3.9.10 protopunica-0.14.8 retrying-1.3.4 scikit-allel-1.3.7 typeguard-4.1.5 typing_extensions-4.8.0 zarr-2.16.1

# %%
import malariagen_data
import allel
import pandas as pd
import numpy as np
import plotly.express as px

# %%
ag3 = malariagen_data.Ag3()

# %%
def average_fst(
    region,
    cohort1_query,
    cohort2_query,
    cohort_size = 10,
    #min_cohort_size = 15,
    #max_cohort_size = 50,
    n_jack = 200,
    site_mask = 'gamb_colu_arab',
    site_class = None,
    random_seed = 42,
):
    # calculate allele counts for each cohort
    cohort1_counts = ag3.snp_allele_counts(
        region=region,
        sample_sets=None,
        sample_query=cohort1_query,
        cohort_size=cohort_size,
        site_mask=site_mask,
        site_class=site_class,
        #min_cohort_size=min_cohort_size,
        #max_cohort_size=max_cohort_size,
        random_seed=random_seed,
    )

    cohort2_counts = ag3.snp_allele_counts(
        region=region,
        sample_sets=None,
        sample_query=cohort2_query,
        cohort_size=cohort_size,
        site_mask=site_mask,
        site_class=site_class,
        #min_cohort_size=min_cohort_size,
        #max_cohort_size=max_cohort_size,
        random_seed=random_seed,
    )

    # calculate block length for blen
    n_sites = cohort1_counts.shape[0]  # number of sites
    block_length = n_sites // n_jack  # number of sites in each block

    # calculate pairwise fst
    fst_hudson, se_hudson, vb_hudson, _ = allel.blockwise_hudson_fst(
        cohort1_counts, cohort2_counts, blen=block_length
    )

    return fst_hudson, se_hudson

# %%
# check data
assert isinstance(fst_hudson, np.float64)
assert isinstance(se_hudson, np.float64)

# check dimensions
assert np.isscalar(fst_hudson)
assert np.isscalar(se_hudson)

# check some values
assert np.allclose(fst_hudson, 0.039983, rtol=1e5), fst_hudson
assert np.allclose(se_hudson, 0.003327, rtol=1e5), se_hudson

# %%
fst_hudson, se_hudson = average_fst(
    region="3L:15,000,000-16,000,000",
    cohort1_query="cohort_admin2_year == 'ML-2_Kati_colu_2014'",
    cohort2_query="cohort_admin2_year == 'ML-2_Kati_gamb_2014'",
    n_jack=200,
    site_mask = 'gamb_colu')
# Out:
# Compute SNP allele counts:   0%|          | 0/44 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/24 [00:00<?, ?it/s]

# %%
fst_hudson
# Out:
# 0.07666678164848241

# %%
se_hudson
# Out:
# 0.0035530631065316047

# %%
def setup_cohorts(
    cohorts,
    sample_sets = None,
    sample_query = None,
    cohort_size = 15,
    #min_cohort_size = None,
):
    if isinstance(cohorts, dict):
        # user has supplied a custom dictionary mapping cohort identifiers
        # to pandas queries
        cohort_queries = cohorts

    elif isinstance(cohorts, str):
        # user has supplied one of the predefined cohort sets
        df_samples = ag3.sample_metadata(
            sample_sets=sample_sets, sample_query=sample_query
        )

        # determine column in dataframe - allow abbreviation
        if cohorts.startswith("cohort_"):
            cohorts_col = cohorts
        else:
            cohorts_col = "cohort_" + cohorts
        if cohorts_col not in df_samples.columns:
            raise ValueError(f"{cohorts_col!r} is not a known cohort set")

        # find cohort labels and build queries dictionary
        cohort_labels = sorted(df_samples[cohorts_col].dropna().unique())
        cohort_queries = {coh: f"{cohorts_col} == '{coh}'" for coh in cohort_labels}

    else:
        raise TypeError("cohorts parameter should be dict or str")

    # handle sample_query parameter
    if sample_query is not None:
        cohort_queries = {
            cohort_label: f"({cohort_query}) and ({sample_query})"
            for cohort_label, cohort_query in cohort_queries.items()
        }

    # check cohort sizes, drop any cohorts which are too small
    cohort_queries_checked = dict()
    for cohort_label, cohort_query in cohort_queries.items():
        df_cohort_samples = ag3.sample_metadata(
            sample_sets=sample_sets, sample_query=cohort_query
        )
        n_samples = len(df_cohort_samples)
        #if min_cohort_size is not None:
            #cohort_size = min_cohort_size
        if n_samples < cohort_size:
            print(
                f"cohort ({cohort_label}) has insufficient samples ({n_samples}) for requested cohort size ({cohort_size}), dropping"
            )
        else:
            cohort_queries_checked[cohort_label] = cohort_query
    return cohort_queries_checked

# %%
cohorts_checked = setup_cohorts('cohort_admin1_year', sample_query = 'country == "Mali" and taxon =="gambiae"')
# Out:
# cohort (ML-4_gamb_2004) has insufficient samples (1) for requested cohort size (15), dropping

# %%
cohorts_checked
# Out:
# {'ML-2_gamb_2004': '(cohort_admin1_year == \'ML-2_gamb_2004\') and (country == "Mali" and taxon =="gambiae")',
#  'ML-2_gamb_2014': '(cohort_admin1_year == \'ML-2_gamb_2014\') and (country == "Mali" and taxon =="gambiae")',
#  'ML-3_gamb_2012': '(cohort_admin1_year == \'ML-3_gamb_2012\') and (country == "Mali" and taxon =="gambiae")'}

# %%
def pairwise_average_fst(
    region,
    cohorts,
    sample_sets = None,
    sample_query = None,
    cohort_size = 10,
    #min_cohort_size = 15,
    #max_cohort_size = 50,
    n_jack = 200,
    site_mask = "gamb_colu_arab",
    site_class = None,
    random_seed = 42,
):
    # set up cohort queries
    cohorts_checked = setup_cohorts(
        cohorts,
        sample_sets=sample_sets,
        sample_query=sample_query,
        cohort_size=cohort_size,
        #min_cohort_size=min_cohort_size,
    )

    cohort_ids = list(cohorts_checked.keys())
    cohort_queries = list(cohorts_checked.values())
    cohort1_ids = []
    cohort2_ids = []
    fst_stats = []
    se_stats = []

    n_cohorts = len(cohorts_checked)
    for i in range(n_cohorts):
        for j in range(i + 1, n_cohorts):
            (
                fst_hudson,
                se_hudson,
            ) = average_fst(
                region=region,
                cohort1_query=cohort_queries[i],
                cohort2_query=cohort_queries[j],
                cohort_size=cohort_size,
                #min_cohort_size=min_cohort_size,
                #max_cohort_size=max_cohort_size,
                n_jack=n_jack,
                site_mask=site_mask,
                site_class=site_class,
                random_seed=random_seed,
            )
            # convert minus numbers to 0
            if fst_hudson < 0:
                fst_hudson = 0
            # add values to lists
            cohort1_ids.append(cohort_ids[i])
            cohort2_ids.append(cohort_ids[j])
            fst_stats.append(fst_hudson)
            se_stats.append(se_hudson)

    fst_df = pd.DataFrame(
        {
            "cohort1": cohort1_ids,
            "cohort2": cohort2_ids,
            "fst": fst_stats,
            "se": se_stats,
        }
    )

    return fst_df

# %%
pairwise_fst_df = pairwise_average_fst(
    region="3L:15,000,000-16,000,000",
    cohorts="cohort_admin1_year",
    sample_query="country == 'Mali' and taxon == 'gambiae'",
    n_jack=200,
    site_mask="gamb_colu",
)
# Out:
# cohort (ML-4_gamb_2004) has insufficient samples (1) for requested cohort size (10), dropping
# Compute SNP allele counts:   0%|          | 0/44 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/24 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/44 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/44 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/24 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/44 [00:00<?, ?it/s]

# %%
pairwise_fst_df
# Out:
#           cohort1         cohort2       fst        se
# 0  ML-2_gamb_2004  ML-2_gamb_2014  0.037250  0.002041
# 1  ML-2_gamb_2004  ML-3_gamb_2012  0.041542  0.002370
# 2  ML-2_gamb_2014  ML-3_gamb_2012  0.000000  0.000814

# %%
test_df = pd.DataFrame(
        {
            "cohort1": [
                'ML-2_gamb_2004',
                'ML-2_gamb_2004',
                'ML-2_gamb_2014',
            ],
            "cohort2": [
                'ML-2_gamb_2014',
                'ML-3_gamb_2012',
                'ML-3_gamb_2012',
            ],
            "fst": [
                0.037249514094550934,
                0.04154191785684654,
                0.0,
            ],
            "se": [
                0.0020406887352541958,
                0.002369740033208285,
                0.0008138514674580574,
            ],
        }
    )

# %%
# check data
assert isinstance(pairwise_fst_df, pd.core.frame.DataFrame)

# check some values
pd.testing.assert_frame_equal(pairwise_fst_df, test_df, rtol=1e5)
assert np.all(pairwise_fst_df["fst"] <= 1)
assert np.all(pairwise_fst_df["fst"] >= -0.05)

# %%
def plot_pairwise_average_fst(
    fst_df,
    annotate_se=True,
    zmin=0,
    zmax=1,
    width=None,
    height=None,
    text_auto=True,
    color_continuous_scale="gray",
    title=None,
    **kwargs,
):
    fst_pivot = fst_df.pivot(
        index="cohort2",
        columns="cohort1",
        values="fst",
    )
    se_pivot = fst_df.pivot(
        index="cohort2",
        columns="cohort1",
        values="se",
    )

    # remove index labels
    fst_pivot = fst_pivot.rename_axis(None, axis=1).rename_axis(None, axis=0)
    se_pivot = se_pivot.rename_axis(None, axis=1).rename_axis(None, axis=0)

    # place SE on upper triangle
    if annotate_se is True:
        se_df = pd.DataFrame(
            np.flip(se_pivot.values), index=se_pivot.index, columns=se_pivot.columns
        )
        fst_pivot = fst_pivot.fillna(se_df)

    # convert to str and 3 decimal places
    for col in fst_pivot:
        new_col = fst_pivot[col].map("{:.3f}".format).astype(str)
        fst_pivot[col] = new_col

    # place empty values on diagonal
    for i in range(min(fst_pivot.shape)):
        fst_pivot.iloc[i, i] = ""

    # create plot
    fig = px.imshow(
        img=fst_pivot,
        zmin=zmin,
        zmax=zmax,
        width=width,
        height=height,
        text_auto=text_auto,
        color_continuous_scale=color_continuous_scale,
        title=title,
        aspect="auto",
        **kwargs,
    )
    fig.update_traces(text=fst_pivot.values, texttemplate="%{text}")
    fig.update_layout(plot_bgcolor="rgba(0,0,0,0)")
    fig.update_yaxes(showgrid=False, linecolor="black")
    fig.update_xaxes(showgrid=False, linecolor="black")

    return fig

# %%
plot_pairwise_average_fst(pairwise_fst_df, annotate_se=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d6c3928a-9dcd-406b-9f59-97d564de0159" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6c3928a-9dcd-406b-9f59-97d564de0159")) {                    Plotly.newPlot(                        "d6c3928a-9dcd-406b-9f59-97d564de0159",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{text}","x":["ML-2_gamb_2004","ML-2_gamb_2014"],"y":["ML-2_gamb_2014","ML-3_gamb_2012"],"z":[["","0.002"],["0.042",""]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e","text":[["","0.002"],["0.042",""]]}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scat ...

# %%
plot_pairwise_average_fst(pairwise_fst_df, annotate_se=False)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c97b70ec-0795-46c2-b775-216e167efb10" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c97b70ec-0795-46c2-b775-216e167efb10")) {                    Plotly.newPlot(                        "c97b70ec-0795-46c2-b775-216e167efb10",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{text}","x":["ML-2_gamb_2004","ML-2_gamb_2014"],"y":["ML-2_gamb_2014","ML-3_gamb_2012"],"z":[["","nan"],["0.042",""]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e","text":[["","nan"],["0.042",""]]}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterp ...
