# %%
import malariagen_data

# %%
# Init Adir1 API
adir1 = malariagen_data.Adir1(results_cache = '/Users/dennistpw/Projects/malariagen_results/')
adir1
# Out:
# <MalariaGEN Adir1 API client>
# Storage URL             : gs://vo_adir_production_us_central1/
# Data releases available : 1.x
# Results cache           : /Users/dennistpw/Projects/malariagen_results
# Site filters analysis   : sc_20250610
# Software version        : malariagen_data 13.3.0.post33+90e72d5a
# Client location         : Queensland, Australia
# ---
# Please note that data are subject to terms of use,
# for more information see https://www.malariagen.net/data
# or contact support@malariagen.net. For API documentation see
# https://malariagen.github.io/malariagen-data-python/v13.3.0.post33+90e72d5a/Adir1.html

# %%
snps = adir1.snp_calls(region="KB672868:1000000-1010000")

# %%
pca = adir1.pca(region = "KB672868", n_snps = 100_000, sample_query = "country == 'Thailand'")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/github/tristanpwdennis/malariagen-data-python/malariagen_data/anoph/sample_metadata.py:581, in AnophelesSampleMetadata.sample_metadata(***failed resolving arguments***)
#     579 try:
#     580     # Attempt to retrieve from the cache.
# --> 581     df_samples = self._cache_sample_metadata[cache_key]
#     583 except KeyError:
#
# KeyError: ('1276-AD-BD-ALAM-VMF00156', '1277-VO-KH-WITKOWSKI-VMF00151', '1277-VO-KH-WITKOWSKI-VMF00183', '1278-VO-TH-KOBYLINSKI-VMF00153')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 pca = adir1.pca(region = "KB672868", n_snps = 100_000, sample_query = "country == 'Thailand'")
#
# ...
