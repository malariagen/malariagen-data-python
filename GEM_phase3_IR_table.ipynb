# %%
import malariagen_data
import pandas as pd
import numpy as np
import allel

# %%
ag3 = malariagen_data.Ag3("simplecache::gs://vo_agam_release/", 
                          simplecache=dict(cache_storage="gcs_cache"))

# %%
meta_df = ag3.sample_metadata()

# %%
# fix the gambia
meta_df.replace('Gambia, The', 'The Gambia', inplace=True)

# %%
meta_df.species.value_counts(dropna=False)
# Out:
# gambiae                            1571
# coluzzii                            675
# arabiensis                          368
# intermediate_gambiae_coluzzii       169
# intermediate_arabiensis_gambiae       1
# Name: species, dtype: int64

# %% [markdown]
# ## kdr
# new column in the metadata that is True for an individual carrying either het/hom 995f/s and False for ref

# %%
# 995S
chrom = '2L'
pos = 2422651
posk, refk, altk = ag3.snp_sites(chrom)
posk = allel.SortedIndex(posk.compute())
gtk = ag3.snp_genotypes(chrom)
loc = posk.locate_key(pos)
gt = gtk[loc].compute()
alt = altk[loc].compute()
ref = refk[loc].compute()
meta_df['kdr_S'] = gt.sum(axis=1) > 0

# %%
# 995S
chrom = '2L'
pos = 2422652
posk, refk, altk = ag3.snp_sites(chrom)
posk = allel.SortedIndex(posk.compute())
gtk = ag3.snp_genotypes(chrom)
loc = posk.locate_key(pos)
gt = gtk[loc].compute()
alt = altk[loc].compute()
ref = refk[loc].compute()
meta_df['kdr_F'] = gt.sum(axis=1) > 0

# %%
# any kdr
meta_df['any_kdr'] = meta_df.kdr_S | meta_df.kdr_F > 0

# %%
# 1570
chrom = '2L'
pos = 2429745
posk, refk, altk = ag3.snp_sites(chrom)
posk = allel.SortedIndex(posk.compute())
gtk = ag3.snp_genotypes(chrom)
loc = posk.locate_key(pos)
gt = gtk[loc].compute()
alt = altk[loc].compute()
ref = refk[loc].compute()
meta_df['kdr_1570'] = gt.sum(axis=1) > 0

# %%
# ace1_G119S = count_alleles('2R', 3492074, 1)
chrom = '2R'
pos = 3492074
posk, refk, altk = ag3.snp_sites(chrom)
posk = allel.SortedIndex(posk.compute())
gtk = ag3.snp_genotypes(chrom)
loc = posk.locate_key(pos)
gt = gtk[loc].compute()
alt = altk[loc].compute()
ref = refk[loc].compute()
meta_df['ace_119s'] = gt.sum(axis=1) > 0

# %%
# gste2_I114T = count_alleles('3R', 28598166, 1)
chrom = '3R'
pos = 28598166
posk, refk, altk = ag3.snp_sites(chrom)
posk = allel.SortedIndex(posk.compute())
gtk = ag3.snp_genotypes(chrom)
loc = posk.locate_key(pos)
gt = gtk[loc].compute()
alt = altk[loc].compute()
ref = refk[loc].compute()
meta_df['gst_114t'] = gt.sum(axis=1) > 0

# %% [markdown]
# ## cnvs
# - add columns to metadata with modal cnv per cyp450 and a True/False column for presence/absence of any cnv
# - cyp6aa/p-(2R) cyp6m-(3R) cyp6z-(3R) cyp9k1-(X)
# - might also make sense here to add some other columns for gste2 cluster and ace1 genes (for OP map)

# %%
# use Erics table for convenience
cnv_df = pd.read_csv("HMM_gene_copy_number.csv", sep=',', index_col=0)

# %%
cnv_df
# Out:
#                          sex  high.var  Ace1  Cyp6aa1  Cyp6aa2  Cyp6p1  \
# sample_id
# AB0333-C                   F     False     0        0        0       0
# AB0457-C                   M     False     0        0        0       0
# AB0502-C                   M     False     0        1        0       0
# AC0007-C                   F     False     0        0        0       0
# AC0008-C                   F     False     0        0        0       0
# ...                       ..       ...   ...      ...      ...     ...
# VBS02119-4431STDY6772831   F     False     0        0        0       0
# VBS02121-4431STDY6772832   F     False     0        0        0       0
# VBS02127-4431STDY6772833   F     False     0        0        0       0
# VBS02129-4431STDY6772835   F     False     0        0        0       0
# VBS02130-4431STDY6772836   F     False     0        0        0       0
#
#                           Cyp6p2  Cyp6p3  Cyp6p4  Cyp6p5  ...  Gste1  Gste2  \
# sample_id                                                 ...
# AB0333-C                       0       0       0       0  ...      2      2
# AB0457-C                       0       0       0       0  ...      2      2
# AB0502-C                       0       0       0       0  ...      0      0
# AC0007-C                       0       0       0       0  ...      0      0
# AC0008-C                       0       0       0       0  ...      0      0
# ...                          ...     ...     ...     ...  ...    ...    ...
# VBS02119-4431STDY6772831       0       0       0       0  ...      0      0
# VBS02121-4431STDY6772832       0       0       0       0  ...      0      0
# VBS02127-4431STDY6772833       0       0       0       0  ...      0      0
# VBS02129-4431STDY6772835       0       0       0       0  ...      0      0
# VBS02130-4431STDY6772836       0       0       0       0  ...      0      0
#
#                           Gste3  Gste4  Gste5  Gste6  Gste7  Gstu4  Max_Gstue  \
# sample_id
# AB0333-C                      0      0      0      0      0      0          2
# AB0457-C                      0      0      0      0      0      0          2
# AB0502-C                      0      0      0      0      0      0          0
# AC0007-C                      0      0      0      0      0      0          0
# AC0008-C                      0      0      0      0      0      0          0
# ...                         ...    ...    ...    ...    ...    ...        ...
# VBS02119-4431STDY6772831      0      0      0      0      0      0          0
# VBS02121-4431STDY6772832      0      0      0      0      0      0          0
# VBS02127-4431STDY6772833      0      0      0      0      0      0          0
# VBS02129-4431STDY6772835      0      0      0      0      0      0          0
# VBS02130-4431STDY6772836      0      0      0      0      0      0          0
#
#                           Cyp9k1
# sample_id
# AB0333-C                       0
# AB0457-C                       0
# AB0502-C                       0
# AC0007-C                       0
# AC0008-C                       0
# ...                          ...
# VBS02119-4431STDY6772831       0
# VBS02121-4431STDY6772832       0
# VBS02127-4431STDY6772833       0
# VBS02129-4431STDY6772835       0
# VBS02130-4431STDY6772836       1
#
# [2783 rows x 28 columns]

# %%
# make a bolean column for any cyp cnv
cyp_list = ['Max_Cyp6aap', 'Max_Cyp6mz', 'Cyp9k1']
cnv_df['any_cyp'] = cnv_df[cyp_list].sum(axis=1) > 0

# %%
cnv_df.head()
# Out:
#           sex  high.var  Ace1  Cyp6aa1  Cyp6aa2  Cyp6p1  Cyp6p2  Cyp6p3  \
# sample_id
# AB0333-C    F     False     0        0        0       0       0       0
# AB0457-C    M     False     0        0        0       0       0       0
# AB0502-C    M     False     0        1        0       0       0       0
# AC0007-C    F     False     0        0        0       0       0       0
# AC0008-C    F     False     0        0        0       0       0       0
#
#            Cyp6p4  Cyp6p5  ...  Gste2  Gste3  Gste4  Gste5  Gste6  Gste7  \
# sample_id                  ...
# AB0333-C        0       0  ...      2      0      0      0      0      0
# AB0457-C        0       0  ...      2      0      0      0      0      0
# AB0502-C        0       0  ...      0      0      0      0      0      0
# AC0007-C        0       0  ...      0      0      0      0      0      0
# AC0008-C        0       0  ...      0      0      0      0      0      0
#
#            Gstu4  Max_Gstue  Cyp9k1  any_cyp
# sample_id
# AB0333-C       0          2       0    False
# AB0457-C       0          2       0    False
# AB0502-C       0          0       0     True
# AC0007-C       0          0       0    False
# AC0008-C       0          0       0    False
#
# [5 rows x 29 columns]

# %% [markdown]
# ## merge

# %%
# let's drop 'AC0198-C' from our meta_df as there is no cnv data for that hybrid sample
meta_df.set_index('sample_id', inplace=True)

# %%
meta_df.drop('AC0198-C', inplace=True)

# %%
merged_df = pd.merge(meta_df, cnv_df, on='sample_id')

# %%
merged_df
# Out:
#           partner_sample_id      contributor country location  year  month  \
# sample_id
# AR0047-C             LUA047       Joao Pinto  Angola   Luanda  2009      4
# AR0049-C             LUA049       Joao Pinto  Angola   Luanda  2009      4
# AR0051-C             LUA051       Joao Pinto  Angola   Luanda  2009      4
# AR0061-C             LUA061       Joao Pinto  Angola   Luanda  2009      4
# AR0078-C             LUA078       Joao Pinto  Angola   Luanda  2009      4
# ...                     ...              ...     ...      ...   ...    ...
# AC0295-C                K92  Martin Donnelly  Uganda   Kihihi  2012     11
# AC0296-C                K93  Martin Donnelly  Uganda   Kihihi  2012     11
# AC0297-C                K94  Martin Donnelly  Uganda   Kihihi  2012     11
# AC0298-C                K95  Martin Donnelly  Uganda   Kihihi  2012     11
# AC0299-C                K96  Martin Donnelly  Uganda   Kihihi  2012     11
#
#            latitude  longitude sex_call  sample_set  ... Gste2  Gste3  Gste4  \
# sample_id                                            ...
# AR0047-C     -8.884     13.302        F  AG1000G-AO  ...     0      0      0
# AR0049-C     -8.884     13.302        F  AG1000G-AO  ...     1      1      1
# AR0051-C     -8.884     13.302        F  AG1000G-AO  ...     0      0      0
# AR0061-C     -8.884     13.302        F  AG1000G-AO  ...     0      0      0
# AR0078-C     -8.884     13.302        F  AG1000G-AO  ...     0      0      0
# ...             ...        ...      ...         ...  ...   ...    ...    ...
# AC0295-C     -0.751     29.701        F  AG1000G-UG  ...     0      0      0
# AC0296-C     -0.751     29.701        F  AG1000G-UG  ...     0      0      0
# AC0297-C     -0.751     29.701        F  AG1000G-UG  ...     0      0      0
# AC0298-C     -0.751     29.701        F  AG1000G-UG  ...     0      0      0
# AC0299-C     -0.751     29.701        F  AG1000G-UG  ...     0      0      0
#
#           Gste5 Gste6 Gste7  Gstu4  Max_Gstue  Cyp9k1  any_cyp
# sample_id
# AR0047-C      0     0     0      0          0       0    False
# AR0049-C      1     1     1      1          1       1     True
# AR0051-C      0     0     0      0          0       0    False
# AR0061-C      0     0     0      0          0       0    False
# AR0078-C      0     0     0      0          0       0    False
# ...         ...   ...   ...    ...        ...     ...      ...
# AC0295-C      0     0     0      0          0       1     True
# AC0296-C      0     0     0      0          0       2     True
# AC0297-C      0     0     0      0          0       2     True
# AC0298-C      0     0     0      0          0       1     True
# AC0299-C      0     0     0      0          0       0    False
#
# [2783 rows x 51 columns]

# %% [markdown]
# ## plot
