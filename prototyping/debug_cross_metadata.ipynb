# %%
import sys
sys.path.insert(0, "..")
import malariagen_data

# %%
ag3 = malariagen_data.Ag3("gs://vo_agam_release")

# %%
df_samples = ag3.sample_metadata(sample_sets="AG1000G-X")
df_samples
# Out:
#     sample_id partner_sample_id      contributor    country location  year  \
# 0    AC0300-C               KF2  Martin Donnelly  Lab Cross     LSTM    -1
# 1    AC0301-C           K2_O_M1  Martin Donnelly  Lab Cross     LSTM    -1
# 2    AC0303-C           K2_O_M3  Martin Donnelly  Lab Cross     LSTM    -1
# 3    AC0304-C           K2_O_M4  Martin Donnelly  Lab Cross     LSTM    -1
# 4    AC0305-C           K2_O_M5  Martin Donnelly  Lab Cross     LSTM    -1
# ..        ...               ...              ...        ...      ...   ...
# 292  AD0494-C         80-2-o-16  Martin Donnelly  Lab Cross     LSTM    -1
# 293  AD0495-C         80-2-o-17  Martin Donnelly  Lab Cross     LSTM    -1
# 294  AD0496-C         80-2-o-18  Martin Donnelly  Lab Cross     LSTM    -1
# 295  AD0497-C         80-2-o-19  Martin Donnelly  Lab Cross     LSTM    -1
# 296  AD0498-C         80-2-o-20  Martin Donnelly  Lab Cross     LSTM    -1
#
#      month  latitude  longitude sex_call sample_set release  \
# ...

# %%
df_samples["sex_call"].value_counts()
# Out:
# M    165
# F    132
# Name: sex_call, dtype: int64

# %%
df_species = ag3.species_calls(sample_sets="AG1000G-X")
df_species
# Out:
#     sample_id  aim_fraction_colu  aim_fraction_arab  \
# 0    AC0300-C                NaN                NaN
# 1    AC0301-C                NaN                NaN
# 2    AC0303-C                NaN                NaN
# 3    AC0304-C                NaN                NaN
# 4    AC0305-C                NaN                NaN
# ..        ...                ...                ...
# 292  AD0494-C                NaN                NaN
# 293  AD0495-C                NaN                NaN
# 294  AD0496-C                NaN                NaN
# 295  AD0497-C                NaN                NaN
# 296  AD0498-C                NaN                NaN
#
#     species_gambcolu_arabiensis species_gambiae_coluzzii species
# 0                           NaN                      NaN     NaN
# 1                           NaN                      NaN     NaN
# 2                           NaN                      NaN     NaN
# 3                           NaN                      NaN     NaN
# ...

# %%
df_crosses = ag3.cross_metadata()
df_crosses
# Out:
#     cross sample_id father_id mother_id sex     role
# 0    18-5  AD0142-C       NaN       NaN   F   parent
# 1    18-5  AD0143-C       NaN       NaN   M   parent
# 2    18-5  AD0163-C  AD0143-C  AD0142-C   M  progeny
# 3    18-5  AD0162-C  AD0143-C  AD0142-C   F  progeny
# 4    18-5  AD0161-C  AD0143-C  AD0142-C   M  progeny
# ..    ...       ...       ...       ...  ..      ...
# 293    K6  AC0346-C  AC0398-C  AC0334-C   M  progeny
# 294    K6  AC0347-C  AC0398-C  AC0334-C   M  progeny
# 295    K6  AC0348-C  AC0398-C  AC0334-C   M  progeny
# 296    K6  AC0335-C  AC0398-C  AC0334-C   M  progeny
# 297    K6  AC0342-C  AC0398-C  AC0334-C   M  progeny
#
# [298 rows x 6 columns]

# %%
df_crosses["sex"].value_counts(dropna=False)
# Out:
# M    166
# F    132
# Name: sex, dtype: int64

# %%
set(df_crosses["sample_id"]) - set(df_samples["sample_id"])
# Out:
# set()

# %%
set(df_samples["sample_id"]) - set(df_crosses["sample_id"])
# Out:
# set()

# %%
len(df_crosses), len(df_samples)
# Out:
# (298, 297)

# %%
len(df_crosses['sample_id'].unique())
# Out:
# 297

# %% [markdown]
# Aah, remember now that one of the parents is a father of two crosses. All should be OK.

# %%
df_crosses[df_crosses['role'] == 'parent']
# Out:
#     cross sample_id father_id mother_id sex    role
# 0    18-5  AD0142-C       NaN       NaN   F  parent
# 1    18-5  AD0143-C       NaN       NaN   M  parent
# 22   29-2  AD0231-C       NaN       NaN   F  parent
# 23   29-2  AD0232-C       NaN       NaN   M  parent
# 44   36-9  AD0254-C       NaN       NaN   F  parent
# 45   36-9  AD0255-C       NaN       NaN   M  parent
# 66   37-3  AD0277-C       NaN       NaN   F  parent
# 67   37-3  AD0278-C       NaN       NaN   M  parent
# 88   42-4  AD0305-C       NaN       NaN   F  parent
# 89   42-4  AD0306-C       NaN       NaN   M  parent
# 104  45-1  AD0324-C       NaN       NaN   F  parent
# 105  45-1  AD0325-C       NaN       NaN   M  parent
# 126  46-9  AD0347-C       NaN       NaN   F  parent
# 127  46-9  AD0348-C       NaN       NaN   M  parent
# 148  47-6  AD0371-C       NaN       NaN   F  parent
# 149  47-6  AD0372-C       NaN       NaN   M  parent
# 170  73-2  AD0422-C       NaN       NaN   F  parent
# ...
