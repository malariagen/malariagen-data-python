# %%
from malariagen_data import Ag3
ag3 = Ag3("gs://vo_agam_release")
ag3

# %%
ds = ag3.snp_dataset(contig="3L")
ds
# Out:
# <xarray.Dataset>
# Dimensions:             (alleles: 4, ploidy: 2, samples: 2784, variants: 40758473)
# Dimensions without coordinates: alleles, ploidy, samples, variants
# Data variables:
#     variant_contig      (variants) uint8 dask.array<chunksize=(524288,), meta=np.ndarray>
#     variant_position    (variants) int32 dask.array<chunksize=(524288,), meta=np.ndarray>
#     variant_allele      (variants, alleles) |S1 dask.array<chunksize=(524288, 1), meta=np.ndarray>
#     sample_id           (samples) object 'AR0047-C' 'AR0049-C' ... 'AC0299-C'
#     call_genotype       (variants, samples, ploidy) int8 dask.array<chunksize=(300000, 50, 2), meta=np.ndarray>
#     call_genotype_mask  (variants, samples, ploidy) bool dask.array<chunksize=(300000, 50, 2), meta=np.ndarray>
# Attributes:
#     contigs:  ('2R', '2L', '3R', '3L', 'X')

# %%
ds['sample_id']
# Out:
# <xarray.DataArray 'sample_id' (samples: 2784)>
# array(['AR0047-C', 'AR0049-C', 'AR0051-C', ..., 'AC0297-C', 'AC0298-C',
#        'AC0299-C'], dtype=object)
# Dimensions without coordinates: samples

# %%
ds['variant_position']
# Out:
# <xarray.DataArray 'variant_position' (variants: 40758473)>
# dask.array<array, shape=(40758473,), dtype=int32, chunksize=(524288,), chunktype=numpy.ndarray>
# Dimensions without coordinates: variants

# %%
ds['call_genotype']
# Out:
# <xarray.DataArray 'call_genotype' (variants: 40758473, samples: 2784, ploidy: 2)>
# dask.array<concatenate, shape=(40758473, 2784, 2), dtype=int8, chunksize=(300000, 50, 2), chunktype=numpy.ndarray>
# Dimensions without coordinates: variants, samples, ploidy

# %%
ds['variant_allele']
# Out:
# <xarray.DataArray 'variant_allele' (variants: 40758473, alleles: 4)>
# dask.array<concatenate, shape=(40758473, 4), dtype=|S1, chunksize=(524288, 3), chunktype=numpy.ndarray>
# Dimensions without coordinates: variants, alleles

# %%
ds['variant_allele'][:5].compute()
# Out:
# <xarray.DataArray 'variant_allele' (variants: 5, alleles: 4)>
# array([[b'A', b'C', b'T', b'G'],
#        [b'C', b'A', b'T', b'G'],
#        [b'G', b'A', b'C', b'T'],
#        [b'A', b'C', b'T', b'G'],
#        [b'A', b'C', b'T', b'G']], dtype='|S1')
# Dimensions without coordinates: variants, alleles
