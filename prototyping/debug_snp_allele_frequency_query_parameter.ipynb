# %%
import malariagen_data

# %%
ag3 = malariagen_data.Ag3()

# %%
meta_df = ag3.sample_metadata()

# %%
meta_df.columns

# %%
df = ag3.gene_cnv_frequencies(
                contig='3L', 
                sample_sets="3.0", 
                cohorts="admin1_year",
                sample_query="country == 'Angola'"
                
            )

# %%
df
# Out:
#            contig     start       end strand      Name  \
# ID
# AGAP010310     3L     66479     82270      -       NaN
# AGAP010311     3L    119223    137112      -       NaN
# AGAP010312     3L    168567    195705      -       NaN
# AGAP010313     3L    293892    306244      -       NaN
# AGAP010314     3L    356758    377200      +       NaN
# ...           ...       ...       ...    ...       ...
# AGAP012420     3L  41851461  41852294      +       NaN
# AGAP029514     3L  41854354  41888460      +       NaN
# AGAP012424     3L  41899845  41941381      +       INR
# AGAP012425     3L  41942987  41948114      -       NaN
# AGAP029618     3L  41950563  41962011      +  GPRNNA16
#
#                                                   description  \
# ID
# AGAP010310  eukaryotic peptide chain release factor subuni...
# AGAP010311  dehydrogenase/reductase SDR family member 11 p...
# AGAP010312             keren [Source:VB Community Annotation]
# AGAP010313  serine/threonine-protein kinase ATR [Source:VB...
# AGAP010314  GPN-loop GTPase [Source:UniProtKB/TrEMBL;Acc:Q...
# ...                                                       ...
# AGAP012420                                                NaN
# AGAP029514                                                NaN
# AGAP012424  insulin receptor [Source:VB Community Annotation]
# AGAP012425                                                NaN
# AGAP029618  putative GPCR class a orphan receptor 16 [Sour...
#
#             frq_AO-LUA_colu_2009_amp  frq_AO-LUA_colu_2009_del
# ID
# AGAP010310                  0.037037                  0.000000
# AGAP010311                  0.234568                  0.000000
# AGAP010312                  0.148148                  0.000000
# AGAP010313                  0.135802                  0.024691
# AGAP010314                  0.259259                  0.000000
# ...                              ...                       ...
# AGAP012420                  0.222222                  0.000000
# AGAP029514                  0.209877                  0.000000
# AGAP012424                  0.172840                  0.000000
# AGAP012425                  0.148148                  0.037037
# AGAP029618                  0.098765                  0.148148
#
# [2211 rows x 8 columns]

# %%
df = ag3.snp_allele_frequencies(
    transcript="AGAP004707-RD",
    cohorts='admin1_year',
    cohorts_analysis="20211101",
    min_cohort_size=10,
    site_mask="gamb_colu",
    sample_sets="3.0",
    drop_invariant=True,
    effects=False,
    sample_query="country == 'Angola'"
)

# %%
df

# %%
df.columns
