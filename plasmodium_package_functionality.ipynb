# %% [markdown]
# ## Pf7

# %% [markdown]
# Current implementation

# %%
from malariagen_data.pf7 import Pf7
# Out:
# ---------------------------------------------------------------------------
# PackageNotFoundError                      Traceback (most recent call last)
# /var/folders/y3/_w18lkrd1nd1sjcl04c2llyr000l9m/T/ipykernel_8930/294316562.py in <module>
# ----> 1 from malariagen_data.pf7 import Pf7
#
# ~/Documents/git_projects/pf7_package_dev/malariagen_master/malariagen-data-python/malariagen_data/__init__.py in <module>
#      13
#      14 # this will read version from pyproject.toml
# ---> 15 __version__ = importlib_metadata.version(__name__)
#
# ~/Documents/git_projects/pf7_package_dev/pf7_env/lib/python3.7/site-packages/importlib_metadata/__init__.py in version(distribution_name)
#     583         "Version" metadata key.
#     584     """
# --> 585     return distribution(distribution_name).version
#     586
#     587
#
# ~/Documents/git_projects/pf7_package_dev/pf7_env/lib/python3.7/site-packages/importlib_metadata/__init__.py in distribution(distribution_name)
#     556     :return: A ``Distribution`` instance (or subclass thereof).
#     557     """
# --> 558     return Distribution.from_name(distribution_name)
#     559
#     560
#
# ~/Documents/git_projects/pf7_package_dev/pf7_env/lib/python3.7/site-packages/importlib_metadata/__init__.py in from_name(cls, name)
#     213                 return dist
#     214         else:
# --> 215             raise PackageNotFoundError(name)
#     216
#     217     @classmethod
#
# PackageNotFoundError: No package metadata was found for malariagen_data

# %%
pf7 = Pf7("gs://pf7_staging/")

# %% [markdown]
# **Metadata**

# %%
pf7.sample_metadata()
# Out:
#           Sample                        Study     Country   Admin level 1  \
# 0       FP0008-C            1147-PF-MR-CONWAY  Mauritania  Hodh el Gharbi
# 1       FP0009-C            1147-PF-MR-CONWAY  Mauritania  Hodh el Gharbi
# 2      FP0010-CW            1147-PF-MR-CONWAY  Mauritania  Hodh el Gharbi
# 3      FP0011-CW            1147-PF-MR-CONWAY  Mauritania  Hodh el Gharbi
# 4      FP0012-CW            1147-PF-MR-CONWAY  Mauritania  Hodh el Gharbi
# ...          ...                          ...         ...             ...
# 20859   SPT43399  1132-PF-K1000G-DBS-KE-BEJON         NaN             NaN
# 20860   SPT43400  1132-PF-K1000G-DBS-KE-BEJON         NaN             NaN
# 20861   SPT43401  1132-PF-K1000G-DBS-KE-BEJON         NaN             NaN
# 20862   SPT43403  1132-PF-K1000G-DBS-KE-BEJON       Kenya          Kilifi
# 20863   SPT43404  1132-PF-K1000G-DBS-KE-BEJON         NaN             NaN
#
#        Country latitude  Country longitude  Admin level 1 latitude  \
# 0             20.265149         -10.337093               16.565426
# 1             20.265149         -10.337093               16.565426
# 2             20.265149         -10.337093               16.565426
# 3             20.265149         -10.337093               16.565426
# 4             20.265149         -10.337093               16.565426
# ...                 ...                ...                     ...
# 20859               NaN                NaN                     NaN
# 20860               NaN                NaN                     NaN
# 20861               NaN                NaN                     NaN
# 20862          0.552741          37.845668               -3.174404
# 20863               NaN                NaN                     NaN
#
#        Admin level 1 longitude    Year         ENA All samples same case  \
# 0                    -9.832345  2014.0  ERR1081237              FP0008-C
# 1                    -9.832345  2014.0  ERR1081238              FP0009-C
# 2                    -9.832345  2014.0  ERR2889621             FP0010-CW
# 3                    -9.832345  2014.0  ERR2889624             FP0011-CW
# 4                    -9.832345  2014.0  ERR2889627             FP0012-CW
# ...                        ...     ...         ...                   ...
# 20859                      NaN     NaN  ERR3486353              SPT43399
# 20860                      NaN     NaN  ERR3486368              SPT43400
# 20861                      NaN     NaN  ERR3486366              SPT43401
# 20862                39.686888  2018.0  ERR3486400              SPT43403
# 20863                      NaN     NaN  ERR3486378              SPT43404
#
#       Population  % callable  QC pass     Exclusion reason Sample type  \
# 0           AF-W       82.16     True         Analysis_set        gDNA
# 1           AF-W       88.85     True         Analysis_set        gDNA
# 2           AF-W       86.46     True         Analysis_set        sWGA
# 3           AF-W       86.35     True         Analysis_set        sWGA
# 4           AF-W       89.74     True         Analysis_set        sWGA
# ...          ...         ...      ...                  ...         ...
# 20859        Lab       93.12    False  Unverified_identity        sWGA
# 20860        Lab       92.90    False  Unverified_identity        sWGA
# 20861        Lab       93.55    False  Unverified_identity        sWGA
# 20862       AF-E        0.01    False         Low_coverage        sWGA
# 20863        Lab       93.64    False  Unverified_identity        sWGA
#
#        Sample was in Pf6
# 0                   True
# 1                   True
# 2                  False
# 3                  False
# 4                  False
# ...                  ...
# 20859              False
# 20860              False
# 20861              False
# 20862              False
# 20863              False
#
# [20864 rows x 17 columns]

# %% [markdown]
# **Variants**

# %%
pf7.variant_calls()
# Out:
# <xarray.Dataset>
# Dimensions:              (variants: 10145661, alleles: 7, samples: 20864, ploidy: 2)
# Coordinates:
#     variant_position     (variants) int32 dask.array<chunksize=(8388608,), meta=np.ndarray>
#     variant_chrom        (variants) object dask.array<chunksize=(4194304,), meta=np.ndarray>
#     sample_id            (samples) object dask.array<chunksize=(20864,), meta=np.ndarray>
# Dimensions without coordinates: variants, alleles, samples, ploidy
# Data variables:
#     variant_allele       (variants, alleles) object dask.array<chunksize=(699051, 1), meta=np.ndarray>
#     variant_filter_pass  (variants) bool dask.array<chunksize=(10145661,), meta=np.ndarray>
#     variant_is_snp       (variants) bool dask.array<chunksize=(10145661,), meta=np.ndarray>
#     variant_numalt       (variants) int32 dask.array<chunksize=(8388608,), meta=np.ndarray>
#     variant_CDS          (variants) bool dask.array<chunksize=(10145661,), meta=np.ndarray>
#     call_genotype        (variants, samples, ploidy) int8 dask.array<chunksize=(167773, 100, 2), meta=np.ndarray>
#     call_AD              (variants, samples, alleles) int16 dask.array<chunksize=(23968, 100, 7), meta=np.ndarray>

# %%
pf7.variant_calls(extended=True)
# Out:
# <xarray.Dataset>
# Dimensions:                                        (variants: 10145661, alleles: 7, samples: 20864, ploidy: 2, genotypes: 3, sb_statistics: 4, alt_alleles: 6)
# Coordinates:
#     variant_position                               (variants) int32 dask.array<chunksize=(8388608,), meta=np.ndarray>
#     variant_chrom                                  (variants) object dask.array<chunksize=(4194304,), meta=np.ndarray>
#     sample_id                                      (samples) object dask.array<chunksize=(20864,), meta=np.ndarray>
# Dimensions without coordinates: variants, alleles, samples, ploidy, genotypes, sb_statistics, alt_alleles
# Data variables: (12/92)
#     variant_allele                                 (variants, alleles) object dask.array<chunksize=(699051, 1), meta=np.ndarray>
#     variant_filter_pass                            (variants) bool dask.array<chunksize=(10145661,), meta=np.ndarray>
#     variant_is_snp                                 (variants) bool dask.array<chunksize=(10145661,), meta=np.ndarray>
#     variant_numalt                                 (variants) int32 dask.array<chunksize=(8388608,), meta=np.ndarray>
#     variant_CDS                                    (variants) bool dask.array<chunksize=(10145661,), meta=np.ndarray>
#     call_genotype                                  (variants, samples, ploidy) int8 dask.array<chunksize=(167773, 100, 2), meta=np.ndarray>
#     ...                                             ...
#     variant_RegionType                             (variants) object dask.array<chunksize=(4194304,), meta=np.ndarray>
#     variant_SOR                                    (variants) float32 dask.array<chunksize=(8388608,), meta=np.ndarray>
#     variant_VQSLOD                                 (variants) float32 dask.array<chunksize=(8388608,), meta=np.ndarray>
#     variant_altlen                                 (variants, alt_alleles) int32 dask.array<chunksize=(1398102, 6), meta=np.ndarray>
#     variant_culprit                                (variants) object dask.array<chunksize=(4194304,), meta=np.ndarray>
#     variant_set                                    (variants) object dask.array<chunksize=(4194304,), meta=np.ndarray>

# %% [markdown]
# **Annotations**

# %%
ann = pf7.genome_features()
# Out:
#             contig source           type  start   end  score strand  phase  \
# 0      Pf3D7_01_v3  chado  repeat_region      1   360    NaN      +    NaN
# 1      Pf3D7_01_v3  chado  repeat_region    361  1418    NaN      +    NaN
# 2      Pf3D7_01_v3  chado  repeat_region   2160  3858    NaN      +    NaN
# 3      Pf3D7_01_v3  chado  repeat_region   8856  9021    NaN      +    NaN
# 4      Pf3D7_01_v3  chado  repeat_region   9313  9529    NaN      +    NaN
# ...            ...    ...            ...    ...   ...    ...    ...    ...
# 40708    Pf_M76611  chado           rRNA   5772  5854    NaN      -    NaN
# 40709    Pf_M76611  chado            CDS   5772  5854    NaN      -    0.0
# 40710    Pf_M76611  chado           gene   5861  5954    NaN      -    NaN
# 40711    Pf_M76611  chado           rRNA   5861  5954    NaN      -    NaN
# 40712    Pf_M76611  chado            CDS   5861  5954    NaN      -    0.0
#
#                                               attributes
# 0      {'ID': 'Pfalciparum_REP_20', 'comment': 'telom...
# 1      {'ID': 'Pfalciparum_REP_15', 'comment': '14bp ...
# 2      {'ID': 'Pfalciparum_REP_35', 'comment': '65bp ...
# 3      {'ID': 'Pfalciparum_REP_5', 'comment': '25bp r...
# 4      {'ID': 'Pfalciparum_REP_25', 'comment': '26bp ...
# ...                                                  ...
# 40708  {'ID': 'PF3D7_MIT04100.1', 'comment': 'fragmen...
# 40709  {'ID': 'PF3D7_MIT04100.1:exon:1', 'Parent': 'P...
# 40710  {'ID': 'PF3D7_MIT04200', 'Name': 'RNA8', 'alia...
# 40711  {'ID': 'PF3D7_MIT04200.1', 'comment': 'transcr...
# 40712  {'ID': 'PF3D7_MIT04200.1:exon:1', 'Parent': 'P...
#
# [40713 rows x 9 columns]

# %%
ann
# Out:
#             contig source           type  start   end  score strand  phase  \
# 0      Pf3D7_01_v3  chado  repeat_region      1   360    NaN      +    NaN
# 1      Pf3D7_01_v3  chado  repeat_region    361  1418    NaN      +    NaN
# 2      Pf3D7_01_v3  chado  repeat_region   2160  3858    NaN      +    NaN
# 3      Pf3D7_01_v3  chado  repeat_region   8856  9021    NaN      +    NaN
# 4      Pf3D7_01_v3  chado  repeat_region   9313  9529    NaN      +    NaN
# ...            ...    ...            ...    ...   ...    ...    ...    ...
# 40708    Pf_M76611  chado           rRNA   5772  5854    NaN      -    NaN
# 40709    Pf_M76611  chado            CDS   5772  5854    NaN      -    0.0
# 40710    Pf_M76611  chado           gene   5861  5954    NaN      -    NaN
# 40711    Pf_M76611  chado           rRNA   5861  5954    NaN      -    NaN
# 40712    Pf_M76611  chado            CDS   5861  5954    NaN      -    0.0
#
#                             ID            Parent  Name       alias
# 0           Pfalciparum_REP_20               NaN   NaN         NaN
# 1           Pfalciparum_REP_15               NaN   NaN         NaN
# 2           Pfalciparum_REP_35               NaN   NaN         NaN
# 3            Pfalciparum_REP_5               NaN   NaN         NaN
# 4           Pfalciparum_REP_25               NaN   NaN         NaN
# ...                        ...               ...   ...         ...
# 40708         PF3D7_MIT04100.1    PF3D7_MIT04100   NaN         NaN
# 40709  PF3D7_MIT04100.1:exon:1  PF3D7_MIT04100.1   NaN         NaN
# 40710           PF3D7_MIT04200               NaN  RNA8  mal_rna_19
# 40711         PF3D7_MIT04200.1    PF3D7_MIT04200   NaN         NaN
# 40712  PF3D7_MIT04200.1:exon:1  PF3D7_MIT04200.1   NaN         NaN
#
# [40713 rows x 12 columns]

# %%
d = {
            "contig": [
                "Pf3D7_01_v3",
                "Pf3D7_02_v3",
                "Pf3D7_03_v3",
                "Pf3D7_04_v3",
                "Pf3D7_05_v3",
            ],
            "source": ["chado"]*5,
            "type": ['repeat_region','CDS','gene','mRNA'],
            "start":[0]*5,
            "end":[0]*5,
            "score":['nan']*5,
            "strand":['+','+','-','-','+'],
            "phase":['nan',0.0,2.0,1.0,2.0],
            "attributes":[{"ID":"id1","Name":"name1", "Parent":"parent1","alias":"alias1","literature":'lit1'},
                          {"ID":"id2","Name":"name2", "Parent":"parent2","alias":"alias2","literature":'lit1'},
                          {"ID":"id3","Name":"name3", "Parent":"parent3","alias":"alias3","literature":'lit1'},
                          {"ID":"id4","Name":"name4", "Parent":"parent4","alias":"alias4","literature":'lit1'},
                          {"ID":"id5","Name":"name5", "Parent":"parent5","alias":"alias5","literature":'lit1'}]
        }
d
# Out:
# {'contig': ['Pf3D7_01_v3',
#   'Pf3D7_02_v3',
#   'Pf3D7_03_v3',
#   'Pf3D7_04_v3',
#   'Pf3D7_05_v3'],
#  'source': ['chado', 'chado', 'chado', 'chado', 'chado'],
#  'type': ['repeat_region', 'CDS', 'gene', 'mRNA'],
#  'start': [0, 0, 0, 0, 0],
#  'end': [0, 0, 0, 0, 0],
#  'score': ['nan', 'nan', 'nan', 'nan', 'nan'],
#  'strand': ['+', '+', '-', '-', '+'],
#  'phase': ['nan', 0.0, 2.0, 1.0, 2.0]}

# %% [markdown]
# ## Pv4

# %% [markdown]
# New Pv4 module

# %%
from malariagen_data.pv4 import Pv4

# %%
pv4 = Pv4("gs://pv4_staging/")

# %% [markdown]
# **Metadata**

# %%
pv4.sample_metadata()

# %% [markdown]
# **Variants**

# %%
pv4.variant_calls()

# %%
pv4.variant_calls(extended=True)

# %%
pv4.variant_calls.__doc__

# %% [markdown]
# **Annotations**

# %%
pv4.genome_features()
# Out:
#              contig source         type  start     end  score strand  phase  \
# 0       PvP01_00_v1  chado       contig      1  402823    NaN      +    NaN
# 1       PvP01_00_v1  chado         gene     53     669    NaN      +    NaN
# 2       PvP01_00_v1  chado         mRNA     53     669    NaN      +    NaN
# 3       PvP01_00_v1  chado          CDS     53     135    NaN      +    0.0
# 4       PvP01_00_v1  chado          CDS    199     415    NaN      +    1.0
# ...             ...    ...          ...    ...     ...    ...    ...    ...
# 38676  PvP01_MIT_v1  chado          CDS   4782    5912    NaN      +    0.0
# 38677  PvP01_MIT_v1  chado  polypeptide   4782    5912    NaN      +    NaN
# 38678  PvP01_MIT_v1  chado         gene   5914    5985    NaN      +    NaN
# 38679  PvP01_MIT_v1  chado         rRNA   5914    5985    NaN      +    NaN
# 38680  PvP01_MIT_v1  chado          CDS   5914    5985    NaN      +    0.0
#
#                               ID            Parent Name alias
# 0      Transfer.PvP01_00_1.final               NaN  NaN   NaN
# 1                  PVP01_0000010               NaN  NaN   NaN
# 2                PVP01_0000010.1     PVP01_0000010  NaN   NaN
# 3         PVP01_0000010.1:exon:1   PVP01_0000010.1  NaN   NaN
# 4         PVP01_0000010.1:exon:2   PVP01_0000010.1  NaN   NaN
# ...                          ...               ...  ...   ...
# 38676    PVP01_MIT03400.1:exon:1  PVP01_MIT03400.1  NaN   NaN
# 38677       PVP01_MIT03400.1:pep               NaN  NaN   NaN
# 38678             PVP01_MIT03500               NaN  NaN   NaN
# 38679           PVP01_MIT03500.1    PVP01_MIT03500  NaN   NaN
# 38680    PVP01_MIT03500.1:exon:1  PVP01_MIT03500.1  NaN   NaN
#
# [38681 rows x 12 columns]

# %% [markdown]
# # Access reference and annotations

# %% [markdown]
# In ag they access reference using genome_sequence
#  ```
#  seq = amin1.genome_sequence(region="KB663610").compute()
#  seq
#  ```
# They have a function to list contigs (`.contigs`), then you specify the contig you want the reference for and it returns a numpy array of that region
#
#
# For annotations they load them into pandas datafram

# %%
from malariagen_data.util import init_filesystem
from Bio import SeqIO
from io import StringIO
import os

# %% [markdown]
# **The below loads the fasta reference and prints the contigs**

# %%
# %%time 
url = "gs://pf7_staging/"
_fs, _path = init_filesystem(url)
path = os.path.join(_path, "reference/Pfalciparum.genome.fasta")
with _fs.open(path) as handle:
    fasta = handle.read().decode('UTF-8')
    fasta_iterator = SeqIO.parse(StringIO(fasta), "fasta")

# Print IDs 
for seq in fasta_iterator:
  print(seq.id)
