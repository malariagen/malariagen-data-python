# %% [markdown]
# # Options for Pv4 package functionality

# %% [markdown]
# 2 options:
# - **pf7 and seperate pv4 module :** back of code is essentially identical, just calling the functions through package
# - **one package** for both and you enter the resource you want : this could become fiddly if resources start to diverge

# %% [markdown]
# ## Pf7

# %% [markdown]
# Current implementation

# %%
from malariagen_data.pf7 import Pf7

# %%
pf7 = Pf7("gs://pf7_staging/")

# %% [markdown]
# ### Metadata

# %%
pf7.sample_metadata()
# Out:
#           Sample                        Study     Country   Admin level 1  \
# 0       FP0008-C            1147-PF-MR-CONWAY  Mauritania  Hodh el Gharbi
# 1       FP0009-C            1147-PF-MR-CONWAY  Mauritania  Hodh el Gharbi
# 2      FP0010-CW            1147-PF-MR-CONWAY  Mauritania  Hodh el Gharbi
# 3      FP0011-CW            1147-PF-MR-CONWAY  Mauritania  Hodh el Gharbi
# 4      FP0012-CW            1147-PF-MR-CONWAY  Mauritania  Hodh el Gharbi
# ...          ...                          ...         ...             ...
# 20859   SPT43399  1132-PF-K1000G-DBS-KE-BEJON         NaN             NaN
# 20860   SPT43400  1132-PF-K1000G-DBS-KE-BEJON         NaN             NaN
# 20861   SPT43401  1132-PF-K1000G-DBS-KE-BEJON         NaN             NaN
# 20862   SPT43403  1132-PF-K1000G-DBS-KE-BEJON       Kenya          Kilifi
# 20863   SPT43404  1132-PF-K1000G-DBS-KE-BEJON         NaN             NaN
#
#        Country latitude  Country longitude  Admin level 1 latitude  \
# ...

# %% [markdown]
# ### Variants

# %%
pf7.variant_calls()
# Out:
# <xarray.Dataset>
# Dimensions:              (variants: 10145661, alleles: 7, samples: 20864, ploidy: 2)
# Coordinates:
#     variant_position     (variants) int32 dask.array<chunksize=(8388608,), meta=np.ndarray>
#     variant_chrom        (variants) object dask.array<chunksize=(4194304,), meta=np.ndarray>
#     sample_id            (samples) object dask.array<chunksize=(20864,), meta=np.ndarray>
# Dimensions without coordinates: variants, alleles, samples, ploidy
# Data variables:
#     variant_allele       (variants, alleles) object dask.array<chunksize=(699051, 1), meta=np.ndarray>
#     variant_filter_pass  (variants) bool dask.array<chunksize=(10145661,), meta=np.ndarray>
#     variant_is_snp       (variants) bool dask.array<chunksize=(10145661,), meta=np.ndarray>
#     variant_numalt       (variants) int32 dask.array<chunksize=(8388608,), meta=np.ndarray>
#     variant_CDS          (variants) bool dask.array<chunksize=(10145661,), meta=np.ndarray>
# ...

# %%
pf7.variant_calls(extended=True)
# Out:
# <xarray.Dataset>
# Dimensions:                                        (variants: 10145661, alleles: 7, samples: 20864, ploidy: 2, genotypes: 3, sb_statistics: 4, alt_alleles: 6)
# Coordinates:
#     variant_position                               (variants) int32 dask.array<chunksize=(8388608,), meta=np.ndarray>
#     variant_chrom                                  (variants) object dask.array<chunksize=(4194304,), meta=np.ndarray>
#     sample_id                                      (samples) object dask.array<chunksize=(20864,), meta=np.ndarray>
# Dimensions without coordinates: variants, alleles, samples, ploidy, genotypes, sb_statistics, alt_alleles
# Data variables: (12/92)
#     variant_allele                                 (variants, alleles) object dask.array<chunksize=(699051, 1), meta=np.ndarray>
#     variant_filter_pass                            (variants) bool dask.array<chunksize=(10145661,), meta=np.ndarray>
# ...

# %% [markdown]
# ## Pv4

# %% [markdown]
# New Pv4 module

# %%
from malariagen_data.pv4 import Pv4

# %%
pv4 = Pv4("gs://pv4_staging/")

# %% [markdown]
# ### Metadata

# %%
pv4.sample_metadata()
# Out:
#            Sample                      Study          Site  \
# 0       BBH-1-125             X0009-PV-ET-LO         Jimma
# 1       BBH_1_132             X0009-PV-ET-LO         Jimma
# 2       BBH_1_137             X0009-PV-ET-LO         Jimma
# 3       BBH_1_153             X0009-PV-ET-LO         Jimma
# 4       BBH_1_162             X0009-PV-ET-LO         Jimma
# ...           ...                        ...           ...
# 1890  india_C1060  X0001-PV-MULTI-HUPALO2016       Chennai
# 1891   malagasy15  X0001-PV-MULTI-HUPALO2016    Madagascar
# 1892   malagasy19  X0001-PV-MULTI-HUPALO2016  Ampasimpotsy
# 1893    malagasy8  X0001-PV-MULTI-HUPALO2016  Ampasimpotsy
# 1894   mauritania  X0001-PV-MULTI-HUPALO2016  Mauritania I
#
#      First-level administrative division     Country        Lat       Long  \
# 0                       Ethiopia: Oromia    Ethiopia   7.683331  36.851318
# 1                       Ethiopia: Oromia    Ethiopia   7.683331  36.851318
# ...

# %% [markdown]
# ### Variants

# %%
pv4.variant_calls()
# Out:
# <xarray.Dataset>
# Dimensions:              (variants: 4571056, alleles: 7, samples: 1895, ploidy: 2)
# Coordinates:
#     variant_position     (variants) int32 dask.array<chunksize=(65536,), meta=np.ndarray>
#     variant_chrom        (variants) object dask.array<chunksize=(65536,), meta=np.ndarray>
#     sample_id            (samples) object dask.array<chunksize=(1895,), meta=np.ndarray>
# Dimensions without coordinates: variants, alleles, samples, ploidy
# Data variables:
#     variant_allele       (variants, alleles) object dask.array<chunksize=(65536, 1), meta=np.ndarray>
#     variant_filter_pass  (variants) bool dask.array<chunksize=(65536,), meta=np.ndarray>
#     variant_is_snp       (variants) bool dask.array<chunksize=(65536,), meta=np.ndarray>
#     variant_numalt       (variants) int32 dask.array<chunksize=(65536,), meta=np.ndarray>
#     variant_CDS          (variants) bool dask.array<chunksize=(65536,), meta=np.ndarray>
# ...

# %%
pv4.variant_calls(extended=True)
# Out:
# <xarray.Dataset>
# Dimensions:                                   (variants: 4571056, alleles: 7, samples: 1895, ploidy: 2, genotypes: 3, alt_alleles: 6)
# Coordinates:
#     variant_position                          (variants) int32 dask.array<chunksize=(65536,), meta=np.ndarray>
#     variant_chrom                             (variants) object dask.array<chunksize=(65536,), meta=np.ndarray>
#     sample_id                                 (samples) object dask.array<chunksize=(1895,), meta=np.ndarray>
# Dimensions without coordinates: variants, alleles, samples, ploidy, genotypes, alt_alleles
# Data variables: (12/42)
#     variant_allele                            (variants, alleles) object dask.array<chunksize=(65536, 1), meta=np.ndarray>
#     variant_filter_pass                       (variants) bool dask.array<chunksize=(65536,), meta=np.ndarray>
#     variant_is_snp                            (variants) bool dask.array<chunksize=(65536,), meta=np.ndarray>
# ...

# %% [markdown]
# ## PlasmodiumData

# %% [markdown]
# Option to have one package which accesses both

# %% [markdown]
# ## Pf7

# %%
from malariagen_data.plasmodium_data import PlasmodiumData

# %%
pf7 = PlasmodiumData('pf7', url="gs://pf7_staging/")

# %% [markdown]
# ### Metadata

# %%
pf7.sample_metadata()
# Out:
#           Sample                        Study     Country   Admin level 1  \
# 0       FP0008-C            1147-PF-MR-CONWAY  Mauritania  Hodh el Gharbi
# 1       FP0009-C            1147-PF-MR-CONWAY  Mauritania  Hodh el Gharbi
# 2      FP0010-CW            1147-PF-MR-CONWAY  Mauritania  Hodh el Gharbi
# 3      FP0011-CW            1147-PF-MR-CONWAY  Mauritania  Hodh el Gharbi
# 4      FP0012-CW            1147-PF-MR-CONWAY  Mauritania  Hodh el Gharbi
# ...          ...                          ...         ...             ...
# 20859   SPT43399  1132-PF-K1000G-DBS-KE-BEJON         NaN             NaN
# 20860   SPT43400  1132-PF-K1000G-DBS-KE-BEJON         NaN             NaN
# 20861   SPT43401  1132-PF-K1000G-DBS-KE-BEJON         NaN             NaN
# 20862   SPT43403  1132-PF-K1000G-DBS-KE-BEJON       Kenya          Kilifi
# 20863   SPT43404  1132-PF-K1000G-DBS-KE-BEJON         NaN             NaN
#
#        Country latitude  Country longitude  Admin level 1 latitude  \
# ...

# %% [markdown]
# ### Variants

# %%
pf7.variant_calls()
# Out:
# <xarray.Dataset>
# Dimensions:              (variants: 10145661, alleles: 7, samples: 20864, ploidy: 2)
# Coordinates:
#     variant_position     (variants) int32 dask.array<chunksize=(8388608,), meta=np.ndarray>
#     variant_chrom        (variants) object dask.array<chunksize=(4194304,), meta=np.ndarray>
#     sample_id            (samples) object dask.array<chunksize=(20864,), meta=np.ndarray>
# Dimensions without coordinates: variants, alleles, samples, ploidy
# Data variables:
#     variant_allele       (variants, alleles) object dask.array<chunksize=(699051, 1), meta=np.ndarray>
#     variant_filter_pass  (variants) bool dask.array<chunksize=(10145661,), meta=np.ndarray>
#     variant_is_snp       (variants) bool dask.array<chunksize=(10145661,), meta=np.ndarray>
#     variant_numalt       (variants) int32 dask.array<chunksize=(8388608,), meta=np.ndarray>
#     variant_CDS          (variants) bool dask.array<chunksize=(10145661,), meta=np.ndarray>
# ...

# %%
pf7.variant_calls(extended=True)
# Out:
# <xarray.Dataset>
# Dimensions:                                        (variants: 10145661, alleles: 7, samples: 20864, ploidy: 2, genotypes: 3, sb_statistics: 4, alt_alleles: 6)
# Coordinates:
#     variant_position                               (variants) int32 dask.array<chunksize=(8388608,), meta=np.ndarray>
#     variant_chrom                                  (variants) object dask.array<chunksize=(4194304,), meta=np.ndarray>
#     sample_id                                      (samples) object dask.array<chunksize=(20864,), meta=np.ndarray>
# Dimensions without coordinates: variants, alleles, samples, ploidy, genotypes, sb_statistics, alt_alleles
# Data variables: (12/92)
#     variant_allele                                 (variants, alleles) object dask.array<chunksize=(699051, 1), meta=np.ndarray>
#     variant_filter_pass                            (variants) bool dask.array<chunksize=(10145661,), meta=np.ndarray>
# ...

# %% [markdown]
# ## Pv4

# %%
pv4 = PlasmodiumData('pv4', url="gs://pv4_staging/")

# %% [markdown]
# ### Metadata

# %%
pv4.sample_metadata()
# Out:
#            Sample                      Study          Site  \
# 0       BBH-1-125             X0009-PV-ET-LO         Jimma
# 1       BBH_1_132             X0009-PV-ET-LO         Jimma
# 2       BBH_1_137             X0009-PV-ET-LO         Jimma
# 3       BBH_1_153             X0009-PV-ET-LO         Jimma
# 4       BBH_1_162             X0009-PV-ET-LO         Jimma
# ...           ...                        ...           ...
# 1890  india_C1060  X0001-PV-MULTI-HUPALO2016       Chennai
# 1891   malagasy15  X0001-PV-MULTI-HUPALO2016    Madagascar
# 1892   malagasy19  X0001-PV-MULTI-HUPALO2016  Ampasimpotsy
# 1893    malagasy8  X0001-PV-MULTI-HUPALO2016  Ampasimpotsy
# 1894   mauritania  X0001-PV-MULTI-HUPALO2016  Mauritania I
#
#      First-level administrative division     Country        Lat       Long  \
# 0                       Ethiopia: Oromia    Ethiopia   7.683331  36.851318
# 1                       Ethiopia: Oromia    Ethiopia   7.683331  36.851318
# ...

# %% [markdown]
# ### Variants

# %%
pv4.variant_calls()
# Out:
# <xarray.Dataset>
# Dimensions:              (variants: 4571056, alleles: 7, samples: 1895, ploidy: 2)
# Coordinates:
#     variant_position     (variants) int32 dask.array<chunksize=(65536,), meta=np.ndarray>
#     variant_chrom        (variants) object dask.array<chunksize=(65536,), meta=np.ndarray>
#     sample_id            (samples) object dask.array<chunksize=(1895,), meta=np.ndarray>
# Dimensions without coordinates: variants, alleles, samples, ploidy
# Data variables:
#     variant_allele       (variants, alleles) object dask.array<chunksize=(65536, 1), meta=np.ndarray>
#     variant_filter_pass  (variants) bool dask.array<chunksize=(65536,), meta=np.ndarray>
#     variant_is_snp       (variants) bool dask.array<chunksize=(65536,), meta=np.ndarray>
#     variant_numalt       (variants) int32 dask.array<chunksize=(65536,), meta=np.ndarray>
#     variant_CDS          (variants) bool dask.array<chunksize=(65536,), meta=np.ndarray>
# ...

# %%
pv4.variant_calls(extended=True)
# Out:
# <xarray.Dataset>
# Dimensions:                                   (variants: 4571056, alleles: 7, samples: 1895, ploidy: 2, genotypes: 3, alt_alleles: 6)
# Coordinates:
#     variant_position                          (variants) int32 dask.array<chunksize=(65536,), meta=np.ndarray>
#     variant_chrom                             (variants) object dask.array<chunksize=(65536,), meta=np.ndarray>
#     sample_id                                 (samples) object dask.array<chunksize=(1895,), meta=np.ndarray>
# Dimensions without coordinates: variants, alleles, samples, ploidy, genotypes, alt_alleles
# Data variables: (12/42)
#     variant_allele                            (variants, alleles) object dask.array<chunksize=(65536, 1), meta=np.ndarray>
#     variant_filter_pass                       (variants) bool dask.array<chunksize=(65536,), meta=np.ndarray>
#     variant_is_snp                            (variants) bool dask.array<chunksize=(65536,), meta=np.ndarray>
# ...

# %% [markdown]
# ### Pf8

# %%
PlasmodiumData('pf8')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/y3/_w18lkrd1nd1sjcl04c2llyr000l9m/T/ipykernel_47753/1619117252.py in <module>
# ----> 1 PlasmodiumData('pf8')
#
# ~/Documents/git_projects/pf7_package_dev/malariagen-data-python/malariagen_data/plasmodium_data.py in __init__(self, resource, data_config, url, **kwargs)
#      33             raise ValueError(
#      34                 "{} is not a data resource option. Options: {}".format(
# ---> 35                     resource, list(self.resource_options.keys())
#      36                 )
#      37             )
#
# ValueError: pf8 is not a data resource option. Options: ['pf7', 'pv4']
